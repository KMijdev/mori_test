# %%
import calc_spice as sp

dirpath="C:\\Users\\e11589\\Desktop\\SPICE_bo"
fname="rawfile_list.csv"
drop_num=1

sp.main(dirpath,fname,drop_num)
# Out:
# pandas ver: 1.5.3
# seaborn ver: 0.12.2
# file_num: 1
# Deprecation Warning! This will no longer be supported in future versions.
# Use 'from PyLTSpice import RawWRead' for a direct import of the Raw Reading class
# ['time', 'V(waveform)', 'V(noz_press)', 'V(meniscus_press)', 'V(meniscus_volume)', 'V(out_volume)', 'V(cham_press)', 'V(spitfile)', 'V(spit_flag)', 'I(Cham_flow)', 'I(Noz_flow)']
# 吐出時間[μs] [7.251968]
# 吐出量＿[pl] [5.70610552]
# 合計吐出量[pl] 5.71
# 累計吐出量[pl] [5.706105517768873]
# ----圧力室振動ピーク----
# x_orimax_trim: [7.1]
# y_orimax_trim: [5.7]
# x_orimin_trim: [3.4]
# y_orimin_trim: [-3.2]
# ----メニスカス振動ピーク----
# x_aftmax_trim: [ 29.7  71.4 110.9]
# y_aftmax_trim: [2.4 0.5 0.1]
# x_aftmin_trim: [ 53.6  97.3 119.4]
# y_aftmin_trim: [-0.9 -0.3  0. ]
# ★peak_aftmax (array([15428, 36750, 47564, 56847, 66500, 76337, 85967], dtype=int64),)
# ★Min_afure_index 15428
# ★peak_slice[0] 15428
# ----メニスカス振動関係指標----
# 減衰比(p): [0.2 0.2]
# メニスカスQ値(p): [2. 2.]
# 減衰比(n): [ 0.3 -0.1]
# メニスカスQ値(n): [2.5 1.4]
# メニスカスQ値(ave): 2.247469957856107
# Meniscus peak 44.73924266666667
#    Unnamed: 0               file       AL    Volume  Afure_max  Afure_min  \
# 0           0  1_G730_水性アナログ.raw  3.72529  5.706106    2.44384   -0.94211
#
#    Afure_score  MeniscusQ_ave  Meniscus_Q_p[0]  Meniscus_Q_p[1]  \
# 0     0.428285        2.24747         2.009906         2.043638
#
#    Meniscus_Q_n[0]  Meniscus_Q_n[1]  total_jetting_vol  fit_gensuihi  \
# 0         2.485034         1.407117           5.706106      0.267703
#
#           A    isou_t     omega  fit_MeniscusQ
# 0  2.381622  0.194342  0.141901       2.383829
